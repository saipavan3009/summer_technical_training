# %% [markdown]
# <a href="https://colab.research.google.com/github/saipavan3009/summer_technical_training/blob/main/summer_technical_training_day_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input())
p=int(input())
x=240-p
c=0
for i in range(1,n+1):
  if x>5*i:
    x=x-5*i
    c+=1
print(c)
# Out:
# 5
# 5
# 5

# %%
inp=input()
hc=0
score=0
for i in inp:
  if i=="H":
    hc+=1
    score+=2
    if hc==3:
      break
  else:
    score-=1
    hc=0
print(score)
# Out:
# HTHTHTH
# 5

# %%
'''digits 4 6                                                                  char_map
        ^    def solve(idx,subset)                                             2:abc
        |     if idx>=len(digits)                                              4:ghi
              result.append("".join(subset))                                   6:mno
                  return
            for ch in char_map[digits[idx]]
                  subset.append(ch)
                  solve(idx+1,subset)
                  subset.pop()
            solve(0,[])
result=[]'''

# %%
'''task
-------
1. problem statement
2. test cases
3. intuition/logic
4. code
5. opimization
6. TC and SC'''


'''
class
------
1. group of similar elements
2. Blueprint, Template, Idea,
'''

# %%
'''
| Feature           | OOP (Object-Oriented Programming)                | Procedural Programming                        |
| ----------------- | ------------------------------------------------ | --------------------------------------------- |
| **Approach**      | Focuses on objects and classes                   | Follows a step-by-step procedure              |
| **Data Handling** | Data is encapsulated within objects              | Data is globally accessible                   |
| **Reusability**   | Uses inheritance to reuse code                   | Code reuse is limited, mostly uses functions  |
| **Security**      | Encapsulation hides data from external access    | No data hiding, making it less secure         |
| **Flexibility**   | Uses polymorphism for flexible and scalable code | Less flexible due to fixed function structure |
| **Complexity**    | Suitable for complex, large-scale applications   | Best for simple, small programs               |
| **Example**       | Java, Python (OOP)                               | C, Pascal (Procedural)                        |

'''

# %%
class A:
  def __init__(self, name, roll, marks):
    self.name=name
    self.roll=roll
    self.marks=marks
    print(name,roll,marks)
obj=A('vivek',1017,8.5)
# Out:
# vivek 1017 8.5

# %%
class Movie:
  def __init__(self,name,hero,heroine,rating):
    self.name=name
    self.hero=hero
    self.heroine=heroine
    self.rating=rating
  def info(self):
    print(f'Movie name is {self.name}')
    print(f'Hero name is {self.hero}')
    print(f'Heroine name is {self.heroine}')
    print(f'Movie rating is {self.rating}')
    print()
movies=[Movie('bahubali','prabhas','anushka',99),
        Movie('spyder','mahesh babu','rakul',69),
        Movie('Rayees','sharukh','sunny',80),
        Movie('sulthan','salmaan','anushka',90)]
for movie in movies:
  movie.info()
# Out:
# Movie name is bahubali
# Hero name is prabhas
# Heroine name is anushka
# Movie rating is 99
#
# Movie name is spyder
# Hero name is mahesh babu
# Heroine name is rakul
# Movie rating is 69
#
# Movie name is Rayees
# Hero name is sharukh
# Heroine name is sunny
# Movie rating is 80
#
# Movie name is sulthan
# Hero name is salmaan
# Heroine name is anushka
# Movie rating is 90

# %%
class Student:
  school_name="VJIT"
  @classmethod
  def change_school(cls,name):
    cls.school_name=name
Student.change_school("CBIT")
print(Student.school_name)
# Out:
# CBIT

# %%
class Student:
  @staticmethod
  def greet():
    print("Hello, welcome to the OOP world!")
Student.greet()
# Out:
# Hello, welcome to the OOP world!

# %%
class Animal:
  def speak(self):
    print("Animal makes a sound")
class Dog(Animal):
  def bark(self):
    print("Dog barks")
d=Dog()
d.speak()
d.bark()
# Out:
# Animal makes a sound
# Dog barks

# %%
# ============================================
# MINI PROJECT
# BANK ACCOUNT MANAGEMENT SYSTEM
# Demonstrates all 4 OOP Pillars in Python
# ============================================

# ----------- ABSTRACTION -----------
# Using abstract class to define common structure

from abc import ABC, abstractmethod


class BankAccount(ABC):

    # ----------- ENCAPSULATION -----------
    # balance is made private using __balance

    def __init__(self, account_holder, account_number, balance):
        self.account_holder = account_holder
        self.account_number = account_number
        self.__balance = balance

    # Getter method
    def get_balance(self):
        return self.__balance

    # Setter method for deposit
    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"₹{amount} deposited successfully.")
        else:
            print("Invalid deposit amount.")

    # Protected method to update balance internally
    def _deduct_balance(self, amount):
        self.__balance -= amount

    # Abstract method (Abstraction)
    @abstractmethod
    def withdraw(self, amount):
        pass

    def display_details(self):
        print("\n------ Account Details ------")
        print("Account Holder :", self.account_holder)
        print("Account Number :", self.account_number)
        print("Balance         :", self.__balance)


# ----------- INHERITANCE -----------
# SavingsAccount inherits BankAccount

class SavingsAccount(BankAccount):

    def __init__(self, account_holder, account_number, balance, interest_rate):
        super().__init__(account_holder, account_number, balance)
        self.interest_rate = interest_rate

    def add_interest(self):
        interest = self.get_balance() * self.interest_rate / 100
        self.deposit(interest)
        print(f"Interest of ₹{interest} added.")

    # ----------- POLYMORPHISM -----------
    # Different withdraw implementation

    def withdraw(self, amount):
        if amount <= self.get_balance():
            self._deduct_balance(amount)
            print(f"₹{amount} withdrawn from Savings Account.")
        else:
            print("Insufficient balance in Savings Account.")


# ----------- INHERITANCE -----------
# CurrentAccount inherits BankAccount

class CurrentAccount(BankAccount):

    def __init__(self, account_holder, account_number, balance, withdrawal_limit):
        super().__init__(account_holder, account_number, balance)
        self.withdrawal_limit = withdrawal_limit

    # ----------- POLYMORPHISM -----------
    # Different withdraw implementation

    def withdraw(self, amount):

        if amount > self.withdrawal_limit:
            print("Withdrawal limit exceeded.")

        elif amount > self.get_balance():
            print("Insufficient balance in Current Account.")

        else:
            self._deduct_balance(amount)
            print(f"₹{amount} withdrawn from Current Account.")


# ============================================
# MAIN PROGRAM
# ============================================

print("======= BANK ACCOUNT MANAGEMENT SYSTEM =======")

# Creating Savings Account Object
savings = SavingsAccount(
    "Sai Pavan",
    1001,
    5000,
    5
)

# Creating Current Account Object
current = CurrentAccount(
    "Rahul",
    2001,
    10000,
    3000
)

# ---------- SAVINGS ACCOUNT OPERATIONS ----------

print("\n===== SAVINGS ACCOUNT =====")

savings.display_details()

savings.deposit(2000)

savings.withdraw(1500)

savings.add_interest()

print("Final Balance :", savings.get_balance())

# ---------- CURRENT ACCOUNT OPERATIONS ----------

print("\n===== CURRENT ACCOUNT =====")

current.display_details()

current.deposit(5000)

current.withdraw(2000)

current.withdraw(5000)   # Exceeds withdrawal limit

print("Final Balance :", current.get_balance())


# ============================================
# OOP PILLARS USED
# ============================================

print("\n\n===== OOP PILLARS DEMONSTRATED =====")

print("1. ENCAPSULATION")
print("   -> Balance is private using __balance")

print("\n2. ABSTRACTION")
print("   -> Abstract class BankAccount with abstract withdraw()")

print("\n3. INHERITANCE")
print("   -> SavingsAccount and CurrentAccount inherit BankAccount")

print("\n4. POLYMORPHISM")
print("   -> withdraw() behaves differently for each account type")
# Out:
# ======= BANK ACCOUNT MANAGEMENT SYSTEM =======
#
# ===== SAVINGS ACCOUNT =====
#
# ------ Account Details ------
# Account Holder : Sai Pavan
# Account Number : 1001
# Balance         : 5000
# ₹2000 deposited successfully.
# ₹1500 withdrawn from Savings Account.
# ₹275.0 deposited successfully.
# Interest of ₹275.0 added.
# Final Balance : 5775.0
#
# ===== CURRENT ACCOUNT =====
#
# ------ Account Details ------
# Account Holder : Rahul
# Account Number : 2001
# Balance         : 10000
# ₹5000 deposited successfully.
# ₹2000 withdrawn from Current Account.
# Withdrawal limit exceeded.
# Final Balance : 13000
#
#
# ===== OOP PILLARS DEMONSTRATED =====
# 1. ENCAPSULATION
#    -> Balance is private using __balance
#
# 2. ABSTRACTION
#    -> Abstract class BankAccount with abstract withdraw()
#
# 3. INHERITANCE
#    -> SavingsAccount and CurrentAccount inherit BankAccount
#
# 4. POLYMORPHISM
#    -> withdraw() behaves differently for each account type
